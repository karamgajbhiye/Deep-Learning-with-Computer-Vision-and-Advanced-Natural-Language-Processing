# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.head(8)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9       NaN
# 6                           8.3        SA
# ...

# %%
#Which continent drinks more beer on average?

# %%
data = df.groupby('continent').mean()

# %%
data.sort_values('beer_servings').tail(1)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU            193.777778       132.555556     142.222222
#
#            total_litres_of_pure_alcohol
# continent
# EU                             8.617778

# %%
#or

# %%
pd.DataFrame(df.groupby('continent').beer_servings.mean())
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
#or

# %%
data = df[['continent','beer_servings']].groupby('continent').mean()

# %%
data
# Out:
#            beer_servings
# continent
# AF             61.471698
# AS             37.045455
# EU            193.777778
# OC             89.687500
# SA            175.083333

# %%
data.sort_values('beer_servings')
# Out:
#            beer_servings
# continent
# AS             37.045455
# AF             61.471698
# OC             89.687500
# SA            175.083333
# EU            193.777778

# %%
data.sort_values('beer_servings').tail(1)
# Out:
#            beer_servings
# continent
# EU            193.777778

# %%
data.sort_values('beer_servings').max()
# Out:
# beer_servings    193.777778
# dtype: float64

# %%
pd.DataFrame(data.sort_values('beer_servings').max())
# Out:
#                         0
# beer_servings  193.777778

# %%
#For each continent print the statistics for wine consumption.

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df[['continent','wine_servings']].groupby('continent').describe()
# Out:
#           wine_servings                                                   \
#                   count        mean        std  min   25%    50%     75%
# continent
# AF                 53.0   16.264151  38.846419  0.0   1.0    2.0   13.00
# AS                 44.0    9.068182  21.667034  0.0   0.0    1.0    8.00
# EU                 45.0  142.222222  97.421738  0.0  59.0  128.0  195.00
# OC                 16.0   35.625000  64.555790  0.0   1.0    8.5   23.25
# SA                 12.0   62.416667  88.620189  1.0   3.0   12.0   98.50
#
#
#              max
# continent
# AF         233.0
# AS         123.0
# EU         370.0
# OC         212.0
# SA         221.0

# %%
#or

# %%
df.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...
